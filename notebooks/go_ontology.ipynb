# %%
import cython
from owlready2 import get_namespace, get_ontology, Thing

# %% [markdown]
# Download:
#
# https://owlready2.readthedocs.io/en/latest/intro.html
#
# https://owlready2.readthedocs.io/en/latest/namespace.html#accessing-entities-defined-in-another-namespace
#
# Accessing content:
#
# https://owlready2.readthedocs.io/en/latest/onto.html#accessing-the-content-of-an-ontology
#
# Methods TODO:
#
# https://owlready2.readthedocs.io/en/latest/class.html
#
#
# ChEBI:
#
# https://ftp.ebi.ac.uk/pub/databases/chebi/ontology/
#
# GO-Plus comes with chebi
#
# http://geneontology.org/docs/download-ontology/
#
#
# Lite (Id, name, definition, and relationships), Core (Lite plus Synonyms) and Full (Core plus database accessions)

# %%
go = get_ontology("../data/raw/ontologies/go-plus.owl").load()
obo = go.get_namespace("http://purl.obolibrary.org/obo/")

terms = set(go.classes())
properties_obj = [p.label for p in go.object_properties()]
properties = [p.label for p in go.properties()]

# %%
list(go.general_axioms())
# Out:
# [obo.RO_0002162.some(Not(obo.NCBITaxon_9989)),
#  obo.RO_0002162.some(obo.NCBITaxon_9989),
#  obo.RO_0002162.some(Not(obo.NCBITaxon_99287)),
#  obo.RO_0002162.some(obo.NCBITaxon_99287),
#  obo.RO_0002162.some(Not(obo.NCBITaxon_9913)),
#  obo.RO_0002162.some(obo.NCBITaxon_9913),
#  obo.RO_0002162.some(Not(obo.NCBITaxon_9903)),
#  obo.RO_0002162.some(obo.NCBITaxon_9903),
#  obo.RO_0002162.some(Not(obo.NCBITaxon_9895)),
#  obo.RO_0002162.some(obo.NCBITaxon_9895),
#  obo.RO_0002162.some(Not(obo.NCBITaxon_9845)),
#  obo.RO_0002162.some(obo.NCBITaxon_9845),
#  obo.RO_0002162.some(Not(obo.NCBITaxon_9823)),
#  obo.RO_0002162.some(obo.NCBITaxon_9823),
#  obo.RO_0002162.some(Not(obo.NCBITaxon_9822)),
#  obo.RO_0002162.some(obo.NCBITaxon_9822),
#  obo.RO_0002162.some(Not(obo.NCBITaxon_9821)),
#  obo.RO_0002162.some(obo.NCBITaxon_9821),
#  obo.RO_0002162.some(Not(obo.NCBITaxon_981071)),
#  obo.RO_0002162.some(obo.NCBITaxon_981071),
#  obo.RO_0002162.some(Not(obo.NCBITaxon_980083)),
# ...

# %%
obo.RO_0002162.label
# Out:
# ['in taxon']

# %%
obo.GO_0022857.get_class_properties()
# Out:
# {obo.IAO_0000115,
#  rdf-schema.label,
#  oboInOwl.hasDbXref,
#  oboInOwl.hasOBONamespace,
#  oboInOwl.inSubset,
#  obo.BFO_0000050,
#  oboInOwl.hasAlternativeId,
#  oboInOwl.id,
#  oboInOwl.hasRelatedSynonym}

# %%
obo.BFO_0000050.label
# Out:
# ['part of']

# %%
type(obo)
# Out:
# owlready2.namespace.Namespace

# %%
chebi = get_ontology("../data/raw/ontologies/chebi.owl").load()
terms = set(chebi.classes())
properties_obj = [p.label for p in chebi.object_properties()]
properties = [p.label for p in chebi.properties()]
list(chebi.annotation_properties())
# Out:
# [rdf-schema.comment,
#  rdf-schema.label,
#  owl.deprecated,
#  oboInOwl.default-namespace,
#  oboInOwl.hasOBOFormatVersion,
#  obo.IAO_0000115,
#  obo.IAO_0000231,
#  oboInOwl.hasDbXref,
#  oboInOwl.hasOBONamespace,
#  oboInOwl.id,
#  oboInOwl.shorthand,
#  obo.IAO_0100001,
#  oboInOwl.SubsetProperty,
#  oboInOwl.SynonymTypeProperty,
#  oboInOwl.hasExactSynonym,
#  oboInOwl.hasAlternativeId,
#  oboInOwl.hasRelatedSynonym,
#  oboInOwl.hasSynonymType,
#  oboInOwl.inSubset,
#  oboInOwl.source,
#  oboInOwl.date,
#  oboInOwl.saved-by,
#  chebi.BRAND_NAME,
#  chebi.INN,
#  chebi.IUPAC_NAME,
#  chebi.1_STAR,
#  chebi.2_STAR,
#  chebi.3_STAR,
#  chebi.charge,
#  chebi.formula,
#  chebi.inchi,
#  chebi.inchikey,
#  chebi.mass,
#  chebi.monoisotopicmass,
#  chebi.smiles,
#  oboInOwl.is_cyclic,
#  oboInOwl.is_transitive]

# %%
obo.CHEBI_178054.get_class_properties()
obo.CHEBI_178054.label
# Out:
# {chebi.charge,
#  chebi.inchikey,
#  rdf-schema.label,
#  chebi.formula,
#  oboInOwl.hasOBONamespace,
#  chebi.smiles,
#  chebi.monoisotopicmass,
#  oboInOwl.inSubset,
#  chebi.inchi,
#  oboInOwl.id,
#  chebi.mass}

# %%
# Out:
# ['4-androsten-3alpha,17alpha-diol 17-sulfate']

# %%
def get_ancestors(cl):
    return cl.ancestors()

test_term = obo.GO_0022857

get_ancestors(test_term)
# Out:
# {obo.GO_0003674, obo.GO_0005215, obo.GO_0022857, owl.Thing}

# %%
ancestors = obo.GO_0022857.ancestors()
print(ancestors)

for ancestor in ancestors:
    print(ancestor.label)
# Out:
# {owl.Thing, obo.GO_0022857, obo.GO_0003674, obo.GO_0005215}
# []
# ['transmembrane transporter activity']
# ['molecular_function']
# ['transporter activity']

# %%
obo["GO_0022857"].is_a
# Out:
# [obo.GO_0005215, obo.BFO_0000050.some(obo.GO_0055085)]

# %%
obo["GO_0022857"].__bases__
# Out:
# (obo.GO_0005215,)

# %%
obo["GO_0022857"].ancestors()
# Out:
# {obo.GO_0003674, obo.GO_0005215, obo.GO_0022857, owl.Thing}

# %%
[(d.name, d.label) for d in obo.GO_0022857.descendants()]
# Out:
# [('GO_0008514', ['organic anion transmembrane transporter activity']),
#  ('GO_0015140', ['malate transmembrane transporter activity']),
#  ('GO_0046583', ['cation efflux transmembrane transporter activity']),
#  ('GO_0005338', ['nucleotide-sugar transmembrane transporter activity']),
#  ('GO_0086075',
#   ['gap junction channel activity involved in cardiac conduction electrical coupling']),
#  ('GO_0090563', ['protein-phosphocysteine-sugar phosphotransferase activity']),
#  ('GO_0015450', ['protein-transporting ATPase activity']),
#  ('GO_0033154', ['ABC-type oligogalacturonide transporter activity']),
#  ('GO_0008331', ['high voltage-gated calcium channel activity']),
#  ('GO_0022848', ['acetylcholine-gated cation-selective channel activity']),
#  ('GO_0005223', ['intracellular cGMP-activated cation channel activity']),
#  ('GO_0046943', ['carboxylic acid transmembrane transporter activity']),
#  ('GO_0099581',
# ...

# %%
[d for d in obo.GO_0022857.is_a]
# Out:
# [obo.GO_0005215, obo.BFO_0000050.some(obo.GO_0055085)]

# %%
len(list(obo.GO_0022857.subclasses()))
# Out:
# 42

# %% [markdown]
# Direct descendants

# %%
[d.label for d in obo.GO_0022857.subclasses()]
# Out:
# [['sulfur compound transmembrane transporter activity'],
#  ['modified amino acid transmembrane transporter activity'],
#  ['toxin transmembrane transporter activity'],
#  ['polyamine transmembrane transporter activity'],
#  ['organophosphate ester transmembrane transporter activity'],
#  ['ion transmembrane transporter activity'],
#  ['inorganic molecular entity transmembrane transporter activity'],
#  ['amide transmembrane transporter activity'],
#  ['amine transmembrane transporter activity'],
#  ['neurotransmitter transmembrane transporter activity'],
#  ['acetate ester transmembrane transporter activity'],
#  ['azole transmembrane transporter activity'],
#  ['organic hydroxy compound transmembrane transporter activity'],
#  ['nucleobase-containing compound transmembrane transporter activity'],
#  ['carbohydrate derivative transmembrane transporter activity'],
#  ['organic acid transmembrane transporter activity'],
#  ['nucleobase transmembrane transporter activity'],
# ...

# %%
[d.label for d in obo.GO_0022857.subclasses()]
# Out:
# [['sulfur compound transmembrane transporter activity'],
#  ['modified amino acid transmembrane transporter activity'],
#  ['toxin transmembrane transporter activity'],
#  ['polyamine transmembrane transporter activity'],
#  ['organophosphate ester transmembrane transporter activity'],
#  ['ion transmembrane transporter activity'],
#  ['inorganic molecular entity transmembrane transporter activity'],
#  ['amide transmembrane transporter activity'],
#  ['amine transmembrane transporter activity'],
#  ['neurotransmitter transmembrane transporter activity'],
#  ['acetate ester transmembrane transporter activity'],
#  ['azole transmembrane transporter activity'],
#  ['organic hydroxy compound transmembrane transporter activity'],
#  ['nucleobase-containing compound transmembrane transporter activity'],
#  ['carbohydrate derivative transmembrane transporter activity'],
#  ['organic acid transmembrane transporter activity'],
#  ['nucleobase transmembrane transporter activity'],
# ...
